# %%
from gensim import corpora, models, similarities

# %%
lda_model = models.LdaModel.load('./trained_model/duozhiwang_model.lda')

# %%
m=lda_model

# %%
m.show_topics(30)
# Out:
# [(0,
#   '0.002*"英语" + 0.002*"在线" + 0.002*"在线教育" + 0.002*"课程" + 0.002*"东方" + 0.002*"新东" + 0.002*"新东方" + 0.002*"学习" + 0.002*"shtml" + 0.001*"学"'),
#  (1,
#   '0.001*"CVC" + 0.001*"游子" + 0.001*"翡翠" + 0.001*"国标" + 0.000*"Udacity" + 0.000*"0119" + 0.000*"图图" + 0.000*"张永琪" + 0.000*"宝马" + 0.000*"克劳"'),
#  (2,
#   '0.001*"审批" + 0.001*"爱乐" + 0.001*"诺亚舟" + 0.001*"诺亚" + 0.001*"金吉列" + 0.001*"吉列" + 0.001*"民办学校" + 0.001*"营利性" + 0.001*"润" + 0.001*"办学"'),
#  (3,
#   '0.001*"耀" + 0.001*"振" + 0.001*"Chegg" + 0.000*"跌停" + 0.000*"赛达" + 0.000*"莎" + 0.000*"扇贝" + 0.000*"赶集" + 0.000*"惠普" + 0.000*"Teach"'),
#  (4,
#   '0.001*"苏宁" + 0.001*"安利" + 0.001*"教师节" + 0.001*"清大" + 0.001*"环球网" + 0.001*"巴克" + 0.001*"星巴克" + 0.001*"声" + 0.001*"Altschool" + 0.001*"球网"'),
#  (5,
#   '0.001*"押" + 0.001*"福" + 0.001*"Instructure" + 0.001*"Canvas" + 0.001*"高考题" + 0.000*"1227" + 0.000*"命中" + 0.000*"心灵鸡汤" + 0.000*"疑点" + 0.000*"葛"'),
#  (6,
#   '0.001*"0902" + 0.001*"时尚" + 0.001*"秦" + 0.001*"聚" + 0.001*"展视" + 0.001*"堂" + 0.000*"Koolearn" + 0.000*"沪江" + 0.000*"网易" + 0.000*"代职"'),
#  (7,
#   '0.002*"E5" + 0.001*"HMHG" + 0.001*"寓" + 0.001*"B9" + 0.001*"后置" + 0.001*"湾" + 0.001*"玥" + 0.001*"Bloc" + 0.001*"E6" + 0.001*"AD"'),
#  (8,
#   '0.001*"20180103120938611" + 0.001*"智联" + 0.001*"0103" + 0.001*"云天" + 0.000*"联招" + 0.000*"AF" + 0.000*"Alpha" + 0.000*"Promethean" + 0.000*"BF" + 0.000*"工业化"'),
#  (9,
#   '0.001*"学生" + 0.001*"学习" + 0.001*"批改" + 0.001*"老师" + 0.001*"分" + 0.001*"高考" + 0.001*"粉笔" + 0.001*"学" + 0.001*"知识" + 0.001*"宝"'),
#  (10,
#   '0.001*"巨人" + 0.001*"塔斯曼" + 0.001*"贝塔斯曼" + 0.001*"9158" + 0.001*"贝塔" + 0.001*"塔斯" + 0.001*"洋" + 0.001*"昂立" + 0.001*"启迪" + 0.001*"乐乐"'),
#  (11,
#   '0.001*"0827" + 0.001*"0324" + 0.001*"夏令营" + 0.001*"夏令" + 0.001*"德拉" + 0.001*"0211" + 0.001*"曰" + 0.001*"ABC" + 0.001*"申论" + 0.001*"Kaplan"'),
#  (12,
#   '0.001*"猿" + 0.001*"嗨" + 0.001*"Blackboard" + 0.001*"题库" + 0.001*"伴" + 0.001*"1124" + 0.001*"歌" + 0.001*"谷" + 0.001*"榜单" + 0.001*"逻"'),
#  (13,
#   '0.001*"Navitas" + 0.001*"nan" + 0.001*"神州" + 0.001*"神州数码" + 0.001*"提价" + 0.001*"洁" + 0.001*"务" + 0.001*"FESCO" + 0.001*"潘鹏凯" + 0.000*"蛙"'),
#  (14,
#   '0.001*"朗" + 0.001*"留学" + 0.001*"傻" + 0.001*"20140930074113110" + 0.001*"新东方" + 0.001*"新东" + 0.001*"东方" + 0.001*"吹牛" + 0.001*"0930" + 0.000*"顿教"'),
#  (15,
#   '0.002*"美元" + 0.002*"万美元" + 0.002*"季度" + 0.001*"去年同期" + 0.001*"一季" + 0.001*"一季度" + 0.001*"同期" + 0.001*"广告" + 0.001*"YY" + 0.001*"百度"'),
#  (16,
#   '0.002*"东方" + 0.002*"留学" + 0.002*"新东方" + 0.002*"新东" + 0.002*"联网" + 0.002*"互联网" + 0.002*"互联" + 0.001*"培训" + 0.001*"公司" + 0.001*"企业"'),
#  (17,
#   '0.002*"Minerva" + 0.001*"ClassDojo" + 0.001*"HMH" + 0.001*"LearnSprout" + 0.001*"1021" + 0.000*"九龙" + 0.000*"计委" + 0.000*"步行" + 0.000*"RRJ" + 0.000*"被调查者"'),
#  (18,
#   '0.002*"决胜" + 0.001*"瑞" + 0.001*"宝" + 0.001*"保" + 0.001*"红包" + 0.001*"美元" + 0.001*"鼎" + 0.001*"钢琴" + 0.001*"信" + 0.001*"微"'),
#  (19,
#   '0.001*"凤凰" + 0.001*"书业" + 0.001*"绵" + 0.000*"机顶" + 0.000*"机顶盒" + 0.000*"顶盒" + 0.000*"建造师" + 0.000*"锦绣" + 0.000*"0430" + 0.000*"特长生"')]

# %%
test_text = "Human computer interaction".split()

# %%
corpora.Dictionary.doc2bow(test_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e0bbcca8f07e> in <module>()
# ----> 1 corpora.Dictionary.doc2bow(test_text)
#
# TypeError: doc2bow() missing 1 required positional argument: 'document'

# %%
m.print_topics(20)
# Out:
# [(0,
#   '0.002*"英语" + 0.002*"在线" + 0.002*"在线教育" + 0.002*"课程" + 0.002*"东方" + 0.002*"新东" + 0.002*"新东方" + 0.002*"学习" + 0.002*"shtml" + 0.001*"学"'),
#  (1,
#   '0.001*"CVC" + 0.001*"游子" + 0.001*"翡翠" + 0.001*"国标" + 0.000*"Udacity" + 0.000*"0119" + 0.000*"图图" + 0.000*"张永琪" + 0.000*"宝马" + 0.000*"克劳"'),
#  (2,
#   '0.001*"审批" + 0.001*"爱乐" + 0.001*"诺亚舟" + 0.001*"诺亚" + 0.001*"金吉列" + 0.001*"吉列" + 0.001*"民办学校" + 0.001*"营利性" + 0.001*"润" + 0.001*"办学"'),
#  (3,
#   '0.001*"耀" + 0.001*"振" + 0.001*"Chegg" + 0.000*"跌停" + 0.000*"赛达" + 0.000*"莎" + 0.000*"扇贝" + 0.000*"赶集" + 0.000*"惠普" + 0.000*"Teach"'),
#  (4,
#   '0.001*"苏宁" + 0.001*"安利" + 0.001*"教师节" + 0.001*"清大" + 0.001*"环球网" + 0.001*"巴克" + 0.001*"星巴克" + 0.001*"声" + 0.001*"Altschool" + 0.001*"球网"'),
#  (5,
#   '0.001*"押" + 0.001*"福" + 0.001*"Instructure" + 0.001*"Canvas" + 0.001*"高考题" + 0.000*"1227" + 0.000*"命中" + 0.000*"心灵鸡汤" + 0.000*"疑点" + 0.000*"葛"'),
#  (6,
#   '0.001*"0902" + 0.001*"时尚" + 0.001*"秦" + 0.001*"聚" + 0.001*"展视" + 0.001*"堂" + 0.000*"Koolearn" + 0.000*"沪江" + 0.000*"网易" + 0.000*"代职"'),
#  (7,
#   '0.002*"E5" + 0.001*"HMHG" + 0.001*"寓" + 0.001*"B9" + 0.001*"后置" + 0.001*"湾" + 0.001*"玥" + 0.001*"Bloc" + 0.001*"E6" + 0.001*"AD"'),
#  (8,
#   '0.001*"20180103120938611" + 0.001*"智联" + 0.001*"0103" + 0.001*"云天" + 0.000*"联招" + 0.000*"AF" + 0.000*"Alpha" + 0.000*"Promethean" + 0.000*"BF" + 0.000*"工业化"'),
#  (9,
#   '0.001*"学生" + 0.001*"学习" + 0.001*"批改" + 0.001*"老师" + 0.001*"分" + 0.001*"高考" + 0.001*"粉笔" + 0.001*"学" + 0.001*"知识" + 0.001*"宝"'),
#  (10,
#   '0.001*"巨人" + 0.001*"塔斯曼" + 0.001*"贝塔斯曼" + 0.001*"9158" + 0.001*"贝塔" + 0.001*"塔斯" + 0.001*"洋" + 0.001*"昂立" + 0.001*"启迪" + 0.001*"乐乐"'),
#  (11,
#   '0.001*"0827" + 0.001*"0324" + 0.001*"夏令营" + 0.001*"夏令" + 0.001*"德拉" + 0.001*"0211" + 0.001*"曰" + 0.001*"ABC" + 0.001*"申论" + 0.001*"Kaplan"'),
#  (12,
#   '0.001*"猿" + 0.001*"嗨" + 0.001*"Blackboard" + 0.001*"题库" + 0.001*"伴" + 0.001*"1124" + 0.001*"歌" + 0.001*"谷" + 0.001*"榜单" + 0.001*"逻"'),
#  (13,
#   '0.001*"Navitas" + 0.001*"nan" + 0.001*"神州" + 0.001*"神州数码" + 0.001*"提价" + 0.001*"洁" + 0.001*"务" + 0.001*"FESCO" + 0.001*"潘鹏凯" + 0.000*"蛙"'),
#  (14,
#   '0.001*"朗" + 0.001*"留学" + 0.001*"傻" + 0.001*"20140930074113110" + 0.001*"新东方" + 0.001*"新东" + 0.001*"东方" + 0.001*"吹牛" + 0.001*"0930" + 0.000*"顿教"'),
#  (15,
#   '0.002*"美元" + 0.002*"万美元" + 0.002*"季度" + 0.001*"去年同期" + 0.001*"一季" + 0.001*"一季度" + 0.001*"同期" + 0.001*"广告" + 0.001*"YY" + 0.001*"百度"'),
#  (16,
#   '0.002*"东方" + 0.002*"留学" + 0.002*"新东方" + 0.002*"新东" + 0.002*"联网" + 0.002*"互联网" + 0.002*"互联" + 0.001*"培训" + 0.001*"公司" + 0.001*"企业"'),
#  (17,
#   '0.002*"Minerva" + 0.001*"ClassDojo" + 0.001*"HMH" + 0.001*"LearnSprout" + 0.001*"1021" + 0.000*"九龙" + 0.000*"计委" + 0.000*"步行" + 0.000*"RRJ" + 0.000*"被调查者"'),
#  (18,
#   '0.002*"决胜" + 0.001*"瑞" + 0.001*"宝" + 0.001*"保" + 0.001*"红包" + 0.001*"美元" + 0.001*"鼎" + 0.001*"钢琴" + 0.001*"信" + 0.001*"微"'),
#  (19,
#   '0.001*"凤凰" + 0.001*"书业" + 0.001*"绵" + 0.000*"机顶" + 0.000*"机顶盒" + 0.000*"顶盒" + 0.000*"建造师" + 0.000*"锦绣" + 0.000*"0430" + 0.000*"特长生"')]

# %%
m.diff()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4f2053703942> in <module>()
# ----> 1 m.diff()
#
# TypeError: diff() missing 1 required positional argument: 'other'

# %%
# -*- coding: UTF-8 -*-
from gensim import corpora,similarities,models
import jieba
# 训练样本
raw_documents = [
    '0南京江心洲污泥偷排”等污泥偷排或处置不当而造成的污染问题，不断被媒体曝光',
    '1面对美国金融危机冲击与国内经济增速下滑形势，中国政府在2008年11月初快速推出“4万亿”投资十项措施',
    '2全国大面积出现的雾霾，使解决我国环境质量恶化问题的紧迫性得到全社会的广泛关注',
    '3大约是1962年的夏天吧，潘文突然出现在我们居住的安宁巷中，她旁边走着40号王孃孃家的大儿子，一看就知道，他们是一对恋人。那时候，潘文梳着一条长长的独辫',
    '4坐落在美国科罗拉多州的小镇蒙特苏马有一座4200平方英尺(约合390平方米)的房子，该建筑外表上与普通民居毫无区别，但其内在构造却别有洞天',
    '5据英国《每日邮报》报道，美国威斯康辛州的非营利组织“占领麦迪逊建筑公司”(OMBuild)在华盛顿和俄勒冈州打造了99平方英尺(约9平方米)的迷你房屋',
    '6长沙市公安局官方微博@长沙警事发布消息称，3月14日上午10时15分许，长沙市开福区伍家岭沙湖桥菜市场内，两名摊贩因纠纷引发互殴，其中一人被对方砍死',
    '7乌克兰克里米亚就留在乌克兰还是加入俄罗斯举行全民公投，全部选票的统计结果表明，96.6%的选民赞成克里米亚加入俄罗斯，但未获得乌克兰和国际社会的普遍承认',
    '8京津冀的大气污染，造成了巨大的综合负面效应，显性的是空气污染、水质变差、交通拥堵、食品不安全等，隐性的是各种恶性疾病的患者增加，生存环境越来越差',
    '9 1954年2月19日，苏联最高苏维埃主席团，在“兄弟的乌克兰与俄罗斯结盟300周年之际”通过决议，将俄罗斯联邦的克里米亚州，划归乌克兰加盟共和国',
    '10北京市昌平区一航空训练基地，演练人员身穿训练服，从机舱逃生门滑降到地面',
    '11腾讯入股京东的公告如期而至，与三周前的传闻吻合。毫无疑问，仅仅是传闻阶段的“联姻”，已经改变了京东赴美上市的舆论氛围',
    '12国防部网站消息，3月8日凌晨，马来西亚航空公司MH370航班起飞后与地面失去联系，西安卫星测控中心在第一时间启动应急机制，配合地面搜救人员开展对失联航班的搜索救援行动',
    '13新华社昆明3月2日电，记者从昆明市政府新闻办获悉，昆明“3·01”事件事发现场证据表明，这是一起由新疆分裂势力一手策划组织的严重暴力恐怖事件',
    '14在即将召开的全国“两会”上，中国政府将提出2014年GDP增长7.5%左右、CPI通胀率控制在3.5%的目标',
    '15中共中央总书记、国家主席、中央军委主席习近平看望出席全国政协十二届二次会议的委员并参加分组讨论时强调，团结稳定是福，分裂动乱是祸。全国各族人民都要珍惜民族大团结的政治局面，都要坚决反对一切危害各民族大团结的言行'
]
corpora_documents = []
#分词处理
for item_text in raw_documents:
    item_seg = list(jieba.cut(item_text))
    corpora_documents.append(item_seg)

# 生成字典和向量语料
dictionary = corpora.Dictionary(corpora_documents)
# print(dictionary)
# dictionary.save('dict.txt') #保存生成的词典
# dictionary=Dictionary.load('dict.txt')#加载

# 通过下面一句得到语料中每一篇文档对应的稀疏向量（这里是bow向量）
corpus = [dictionary.doc2bow(text) for text in corpora_documents]
# 向量的每一个元素代表了一个word在这篇文档中出现的次数
# print(corpus)
# corpora.MmCorpus.serialize('corpuse.mm',corpus)#保存生成的语料
# corpus=corpora.MmCorpus('corpuse.mm')#加载

# corpus是一个返回bow向量的迭代器。下面代码将完成对corpus中出现的每一个特征的IDF值的统计工作
tfidf_model = models.TfidfModel(corpus)
corpus_tfidf = tfidf_model[corpus]


#查看model中的内容
# for item in corpus_tfidf:
#     print(item)
# corpus_tfidf.serialize("data.tfidf")
# tfidf_model = models.TfidfModel.load("data.tfidf")
# print(tfidf_model.dfs)

similarity = similarities.Similarity('Similarity-tfidf-index', corpus_tfidf, num_features=600)
test_data_1 = '北京雾霾红色预警'
test_cut_raw_1 = list(jieba.cut(test_data_1))  # ['北京', '雾', '霾', '红色', '预警']
test_corpus_1 = dictionary.doc2bow(test_cut_raw_1)  # [(51, 1), (59, 1)]，即在字典的56和60的地方出现重复的字段，这个值可能会变化
similarity.num_best = 5
test_corpus_tfidf_1=tfidf_model[test_corpus_1]  # 根据之前训练生成的model，生成query的IFIDF值，然后进行相似度计算
                                                # [(51, 0.7071067811865475), (59, 0.7071067811865475)]
print(similarity[test_corpus_tfidf_1])  # 返回最相似的样本材料,(index_of_document, similarity) tuples

print('-'*40)

test_data_2 = '长沙街头发生砍人事件致6人死亡'
test_cut_raw_2 = list(jieba.cut(test_data_2))
test_corpus_2 = dictionary.doc2bow(test_cut_raw_2)
test_corpus_tfidf_2=tfidf_model[test_corpus_2]
similarity.num_best = 3
print(similarity[test_corpus_tfidf_2])  # 返回最相似的样本材料,(index_of_document, similarity) tuples

# 使用LSI模型进行相似度计算
lsi = models.LsiModel(corpus_tfidf)
corpus_lsi = lsi[corpus_tfidf]
similarity_lsi=similarities.Similarity('Similarity-LSI-index', corpus_lsi, num_features=400,num_best=3)
# save
# LsiModel.load(fname, mmap='r')#加载
test_data_3 = '长沙街头发生砍人事件致6人死亡'
test_cut_raw_3 = list(jieba.cut(test_data_3))         # 1.分词
test_corpus_3 = dictionary.doc2bow(test_cut_raw_3)  # 2.转换成bow向量
test_corpus_tfidf_3 = tfidf_model[test_corpus_3]  # 3.计算tfidf值
test_corpus_lsi_3 = lsi[test_corpus_tfidf_3]  # 4.计算lsi值
#lsi.add_documents(test_corpus_lsi_3) #更新LSI的值
print('-'*40)
print(similarity_lsi[test_corpus_lsi_3])
# Out:
# [(2, 0.35959327220916748)]
# ----------------------------------------
# [(6, 0.19451555609703064), (13, 0.10124017298221588)]
# ----------------------------------------
# [(6, 0.89239442348480225), (13, 0.4644676148891449), (10, -6.1700120568275452e-08)]

# %%
test_corpus_tfidf_3
# Out:
# [(152, 0.5773502691896258),
#  (182, 0.5773502691896258),
#  (315, 0.5773502691896258)]

# %%
corpus_tfidf

# %%
ls
# Out:
# Similarity-LSI-index.0    __pycache__/              nlp.py
# Similarity-tfidf-index.0  data.tfidf                stopwords.txt
# Untitled.ipynb            mydict.txt                trained_model/

# %%
import pickle
texts_pickle="./trained_model/cbnweek"
texts=[]
with open(texts_pickle+'_texts'+'.pickle', 'rb') as handle:
    texts = pickle.load(handle)
    print(len(texts))
# Out:
# 15425

# %%
t=texts

# %%
t[57]
# Out:
# ['https://www.cbnweek.com/articles/magazine/13207',
#  '如有',
#  '本文',
#  '文娱',
#  '圈',
#  '字典',
#  '找',
#  '偶像',
#  '颜',
#  '值',
#  '天王',
#  '天',
#  '天',
#  '团',
#  '永远',
#  '远处',
#  '风口',
#  '词语',
#  '找到',
#  '词',
#  '摇滚',
#  '只能',
#  '挑选',
#  '类型',
#  '喜好',
#  '选',
#  '摇滚',
#  '精神',
#  '层面',
#  '站',
#  '鄙视',
#  '链',
#  '顶端',
#  '端的',
#  '优越',
#  '优越感',
#  '越感',
#  '摇滚',
#  '精神',
#  '信仰',
#  '挂钩',
#  '艺术',
#  '形式',
#  '楼下',
#  'Rebecca',
#  '买',
#  '一罐',
#  '元',
#  '钱',
#  '饮',
#  '咖啡',
#  '朋友',
#  '讨论',
#  '第三',
#  '第三次',
#  '三次',
#  '咖啡',
#  '浪潮',
#  '蓝',
#  '瓶子',
#  '确有',
#  '一点',
#  '装',
#  '嫌疑',
#  '懂得',
#  '欣赏',
#  '承担',
#  '欣赏',
#  '精神',
#  '自豪',
#  '资本',
#  '摇滚',
#  '挺',
#  '难',
#  '回答',
#  '反过',
#  '解释',
#  '摇滚',
#  '如一',
#  '一群',
#  '摇滚',
#  '炮',
#  '安静',
#  '静地',
#  '坐在',
#  '红色',
#  '色标',
#  '标语',
#  '红木',
#  '长桌',
#  '桌前',
#  '开',
#  '中国',
#  '摇滚',
#  '30',
#  '周年',
#  '回顾',
#  '展望',
#  '研讨',
#  '研讨会',
#  '不管怎么',
#  '摇滚',
#  '音乐',
#  '角度',
#  '摇滚',
#  '至少',
#  '该是',
#  '低音',
#  '节奏',
#  '炮制',
#  '制出',
#  '热血',
#  '热血沸腾',
#  '沸腾',
#  '里',
#  '找到',
#  '感',
#  '自带',
#  '颠覆',
#  '精神',
#  '离经叛道',
#  '里',
#  '找到',
#  '独有',
#  '方向',
#  '大部',
#  '大部分',
#  '人眼',
#  '眼中',
#  '摇滚',
#  '咖',
#  '一套',
#  '鲜明',
#  '造型',
#  '留',
#  '飘逸',
#  '长发',
#  '弄',
#  '爆炸',
#  '发型',
#  '蛤蟆',
#  '墨镜',
#  '身着',
#  '皮衣',
#  '皮',
#  '裤',
#  '想',
#  '表达',
#  '很爽',
#  '情绪',
#  '比出',
#  '标志',
#  'Rock',
#  'Roll',
#  '手势',
#  '回答',
#  '验证',
#  '手势',
#  '金属',
#  '礼',
#  '我爱你',
#  '貌似',
#  '摇滚',
#  '摇滚圈',
#  '滚圈',
#  '不在',
#  '不在意',
#  '在意',
#  '之间',
#  '摇滚',
#  '跳出',
#  '音乐',
#  '和文',
#  '文化',
#  '框框',
#  '一种',
#  '广义',
#  '精神',
#  '时',
#  '更多',
#  '答案',
#  '四五',
#  '四五十',
#  '四五十岁',
#  '五十',
#  '五十岁',
#  '十岁',
#  '摇滚',
#  '答案',
#  '摇滚',
#  '看做',
#  '自我',
#  '感情',
#  '表达',
#  '自我',
#  '追求',
#  '精神',
#  '自由',
#  '意味',
#  '意味着',
#  '摇滚',
#  '事',
#  '轰轰',
#  '轰轰烈烈',
#  '烈烈',
#  '走',
#  '寻常',
#  '寻常路',
#  '想',
#  '小燕子',
#  '燕子',
#  '阿哥',
#  '拨',
#  '最早',
#  '早在',
#  '年少',
#  '年少时',
#  '少时',
#  '灌输',
#  '摇滚',
#  '思想',
#  '领路',
#  '领路人',
#  '路人',
#  '红尘',
#  '作伴',
#  '活得',
#  '潇潇',
#  '潇潇洒洒',
#  '潇洒',
#  '洒洒',
#  '策马',
#  '马奔腾',
#  '奔腾',
#  '共享',
#  '人世',
#  '繁华',
#  '如果说',
#  '人心',
#  '一颗',
#  '摇滚',
#  '种子',
#  '摇滚',
#  '事情',
#  '在读',
#  '读者',
#  '故事',
#  '征集',
#  '答案',
#  '千奇百怪',
#  '值得',
#  '深思',
#  '有趣',
#  '舒缓',
#  '慢',
#  '歌',
#  '刺激',
#  '振聋发',
#  '振聋发聩',
#  '音符',
#  '节奏',
#  '响应',
#  '心中',
#  '呐喊',
#  '平淡',
#  '平淡无奇',
#  '无奇',
#  '日子',
#  '里',
#  '喜欢',
#  '生活',
#  '加点',
#  '料',
#  '摇滚',
#  '范',
#  '明明',
#  '坐',
#  '飞机',
#  '高铁',
#  '到达',
#  '地方',
#  '有人',
#  '选择',
#  '慢',
#  '上好',
#  '好几',
#  '好几倍',
#  '几倍',
#  '绿皮',
#  '火车',
#  '车上',
#  '萍水',
#  '萍水相逢',
#  '相逢',
#  '朋友',
#  '看着',
#  '沿途',
#  '风景',
#  '唱着歌',
#  '至少',
#  '少选',
#  '选择',
#  '方式',
#  '一种',
#  '勇气',
#  '自我',
#  '崇尚',
#  '摇滚',
#  '文化',
#  '青年',
#  'ta',
#  '会去',
#  '音乐',
#  '音乐节',
#  '交通',
#  '交通不便',
#  '不便',
#  '黄沙',
#  '黄沙滚滚',
#  '滚滚',
#  '如厕',
#  '扔',
#  '垃圾',
#  '体验',
#  '不愉',
#  '愉快',
#  '要能',
#  '台下',
#  '举起',
#  '双手',
#  '跟着',
#  '音乐',
#  '摇摆',
#  '摆起',
#  '摆起来',
#  '玩',
#  'pogo',
#  '开心',
#  '心得',
#  '数字',
#  '字音',
#  '音乐',
#  '时代',
#  'ta',
#  '想尽',
#  '想尽办法',
#  '办法',
#  '搜集',
#  '搜集自',
#  '喜欢',
#  '摇滚',
#  '摇滚乐',
#  '摇滚乐手',
#  '乐手',
#  'CD',
#  '黑胶',
#  '唱片',
#  '一场',
#  '演唱',
#  '演唱会',
#  '站',
#  '腿软',
#  '刮风',
#  '刮风下雨',
#  '下雨',
#  '排队',
#  '买到',
#  '票',
#  'ta',
#  '同好',
#  '朋友',
#  'livehouse',
#  '当做',
#  '圣地',
#  '窝',
#  '房间',
#  '里',
#  '喝',
#  '酒',
#  '沉醉',
#  '沉醉在',
#  '音乐',
#  '里',
#  '捣鼓',
#  '乐队',
#  'ta',
#  '幻想',
#  '想着',
#  '现实',
#  '现实生活',
#  '生活',
#  '乐手',
#  '一段',
#  '旷世',
#  '旷世奇',
#  '恋',
#  '深夜',
#  '大街',
#  '街上',
#  '吵吵',
#  '吵吵嚷嚷',
#  '吵嚷',
#  '嚷嚷',
#  '哼歌',
#  '暴走',
#  'ta',
#  '会用',
#  '态度',
#  '生活',
#  'ta',
#  '青春',
#  '年代',
#  '一部',
#  '一部分',
#  '摇滚',
#  '感情',
#  '外露',
#  '非要',
#  '拗',
#  '造型',
#  '外界',
#  '喧嚣',
#  '在内',
#  '内心',
#  '默默',
#  '一种',
#  '东西',
#  '算是',
#  '摇滚',
#  '精神',
#  'cbnweek',
#  '85009345e327383b5ad9d22bf690e3a1',
#  '300x300',
#  '豪放',
#  '豪放派',
#  '摇滚',
#  '大声',
#  '大声疾呼',
#  '疾呼',
#  '是因为',
#  '摇滚',
#  '摇滚乐',
#  '震耳',
#  '震耳欲聋',
#  '感觉',
#  '摇滚',
#  '看做',
#  '宣泄',
#  '呐喊',
#  '舒缓',
#  '心中',
#  '块垒',
#  '方式',
#  '登上',
#  '上山',
#  '山顶',
#  '走到',
#  '海边',
#  '站上',
#  '舞台',
#  '面朝',
#  '一块',
#  '空地',
#  '地大',
#  '大声',
#  '大声疾呼',
#  '疾呼',
#  '地点',
#  '仪式',
#  '眼光',
#  '不重',
#  '不爽',
#  '喊',
#  '心灵',
#  '解放',
#  '一点',
#  '说走就走',
#  '旅行',
#  '火',
#  '营销',
#  '活动',
#  '某天',
#  '早上',
#  '点',
#  '小时',
#  '赶到',
#  '北京',
#  '上海',
#  '广州',
#  '城市',
#  '机场',
#  '前',
#  '30',
#  '一张',
#  '目的',
#  '目的地',
#  '未知',
#  '往返',
#  '往返机票',
#  '机票',
#  '一共',
#  '共有',
#  '万',
#  '人参',
#  '参与',
#  '活动',
#  '里',
#  '料想',
#  '一场',
#  '说走就走',
#  '旅行',
#  '世界',
#  '想去',
#  '情结',
#  '受欢迎',
#  '现实',
#  '现实生活',
#  '生活',
#  '有人',
#  '真的',
#  '工作',
#  '累',
#  '请假',
#  '坐飞机',
#  '飞机',
#  '走人',
#  '情场',
#  '情场失意',
#  '失意',
#  '过后',
#  '一场',
#  '旅行',
#  '疗伤',
#  '洒脱',
#  '不羁',
#  '摇滚',
#  '解释',
#  '最常',
#  '常见',
#  '一种',
#  '想来',
#  '一场',
#  '说走就走',
#  '侠客',
#  '侠客行',
#  '先',
#  '工作',
#  '周遭',
#  '事务',
#  '安排',
#  '排好',
#  '爽',
#  '苦',
#  '还给',
#  '摇滚',
#  '不负',
#  '不负责任',
#  '负责',
#  '责任',
#  '骂名',
#  '拿出',
#  '勇气',
#  '有人',
#  '摇滚',
#  '年轻',
#  '看上',
#  '很傻',
#  '事',
#  '众',
#  '好友',
#  '动作',
#  '表情',
#  '古怪',
#  '合照',
#  '晚自习',
#  '自习',
#  '时',
#  '扫帚',
#  '教室',
#  '摇头',
#  '摇头晃脑',
#  '嘶吼',
#  '一曲',
#  '时过境迁',
#  '过境',
#  '迁',
#  '事',
#  '定义',
#  '傻',
#  '勇气',
#  '现实',
#  '现实生活',
#  '生活',
#  '少时',
#  '勇气',
#  '勇气可嘉',
#  '可嘉',
#  '本来',
#  '一份',
#  '薪水',
#  '还过',
#  '还过得去',
#  '过得去',
#  '安稳',
#  '工作',
#  '从零开始',
#  '创业',
#  '恐高症',
#  '要用',
#  '蹦极',
#  '跳伞',
#  '克服',
#  '恐惧',
#  '小城',
#  '城市',
#  '市里',
#  '一套',
#  '套房',
#  '大城',
#  '大城市',
#  '城市',
#  '市里',
#  '一张',
#  '床',
#  '之间',
#  '选择',
#  '看似',
#  '难',
#  '台湾',
#  '广告',
#  '里',
#  '一群',
#  '头发',
#  '稀疏',
#  '脸上',
#  '布满',
#  '皱纹',
#  '老爷',
#  '老爷爷',
#  '爷爷',
#  '骑',
#  '摩托',
#  '摩托车',
#  '托车',
#  '一场',
#  '旅行',
#  '拿出',
#  '勇气',
#  '跳出',
#  '舒适',
#  '圈',
#  '范',
#  '一言',
#  '一言不合',
#  '不合',
#  '摇滚',
#  '刻板',
#  '印象',
#  '太',
#  '深',
#  '暴躁',
#  '冲动',
#  '我行',
#  '我行我素',
#  '翻译',
#  '日常',
#  '日常生活',
#  '常生',
#  '生活',
#  '一言',
#  '一言不合',
#  '不合',
#  '电光',
#  '光火',
#  '火石',
#  '之间',
#  '前女友',
#  '女友',
#  '现',
#  '男友',
#  '闪电',
#  '交往',
#  '闪电',
#  '闪电结婚',
#  '结婚',
#  '物质',
#  '充足',
#  '情况',
#  '裸',
#  '婚',
#  '闪电',
#  '电离',
#  '离婚',
#  '算',
#  '没来',
#  '来得',
#  '脑',
#  '跟上',
#  '上司',
#  '杠',
#  '干脆',
#  '撂下',
#  '下工',
#  '牌',
#  '裸',
#  '辞',
#  '事',
#  '稍微',
#  '微冷',
#  '冷静',
#  '冷静下来',
#  '静下',
#  '静下来',
#  '想',
#  '种种',
#  '不妥',
#  '但有',
#  '住',
#  '一颗',
#  '血脉',
#  '贲',
#  '张',
#  '少年',
#  '心',
#  '并不需要',
#  '太多',
#  '思前想后',
#  '跟着',
#  '感觉',
#  '走',
#  '摇滚',
#  '一种',
#  'cbnweek',
#  'dbbd4bf1cbe30eabd2d535574181d437',
#  '300x500',
#  '婉约',
#  '婉约派',
#  '摇滚',
#  '盲从',
#  '跟随',
#  '收集',
#  '诸多',
#  '回答',
#  '简短',
#  '句子',
#  '颇为',
#  '亮眼',
#  '摇滚',
#  '一件',
#  '事',
#  '是从',
#  '从来没',
#  '摇滚',
#  '津津',
#  '津津乐道',
#  '乐道',
#  '一件',
#  '事情',
#  '时',
#  '承认',
#  '拨',
#  '没接',
#  '接触',
#  '欣赏',
#  '不来',
#  '勇气',
#  '跟随',
#  '喜好',
#  '喜好',
#  '影响',
#  '了不起',
#  '事',
#  '持之以恒',
#  '一件',
#  '事',
#  '脑',
#  '热',
#  '喜欢',
#  '事物',
#  '不算',
#  '不算什么',
#  '日后',
#  '一种',
#  '境界',
#  '食',
#  '素',
#  '买',
#  '东西',
#  '西都',
#  '选择',
#  '环保',
#  '那种',
#  '500',
#  '投篮',
#  '风雨',
#  '无阻',
#  '接送',
#  '心仪',
#  '姑娘',
#  '苦行',
#  '苦行僧',
#  '行僧',
#  '做法',
#  '看上',
#  '追求',
#  '无拘',
#  '无拘无束',
#  '摇滚',
#  '搭边',
#  '过程',
#  '克服',
#  '懒惰',
#  '困难',
#  '异样',
#  '眼光',
#  '并不比',
#  '比做',
#  '摇滚',
#  '青年',
#  '不解',
#  '少',
#  '哪种',
#  '全世界',
#  '世界',
#  '敌',
#  '状态',
#  '一日',
#  '一件',
#  '事',
#  '爽',
#  '出格',
#  '之举',
#  '力量',
#  '某种',
#  '价值',
#  '价值观',
#  '摇滚',
#  '精神',
#  '以是',
#  '认定',
#  '正确',
#  '事情',
#  '不顾',
#  '人眼',
#  '眼光',
#  '不惧',
#  '孤独',
#  '是从',
#  '10',
#  '年前',
#  '买',
#  '正版',
#  'CD',
#  '淘宝',
#  '购物',
#  '有意',
#  '避开',
#  '盗版',
#  '同事',
#  '风口',
#  '创业',
#  '内心',
#  '毫不动摇',
#  '不动',
#  '动摇',
#  '留在',
#  '行业',
#  '朋友',
#  '朋友圈',
#  '圈里',
#  '转',
#  '中国',
#  '国人',
#  '大声',
#  '大声疾呼',
#  '疾呼',
#  '时',
#  '冷静',
#  '煽动',
#  '孤独',
#  '坚守',
#  '正确',
#  '事',
#  '算',
#  '默默',
#  '默默无闻',
#  '无闻',
#  '版',
#  '轰轰',
#  '轰轰烈烈',
#  '烈烈',
#  'cbnweek',
#  'ebf45b39a484ee44ef25b35f4a92ddab',
#  '400x300',
#  '摇滚',
#  '离经叛道',
#  '狂放',
#  '背后',
#  '寻常',
#  '常生',
#  '生活',
#  '摇滚',
#  '扣上',
#  '狂放',
#  '狂放不羁',
#  '不羁',
#  '性',
#  '帽子',
#  '酗酒',
#  '嗑',
#  '药',
#  '描述',
#  '场景',
#  '鲍',
#  '勃',
#  '迪伦',
#  '和约',
#  '约翰',
#  '列',
#  '侬',
#  '吸毒',
#  '史',
#  '摇滚',
#  '摇滚乐',
#  '乐队',
#  '成员',
#  '观众',
#  '打起',
#  '舞台',
#  '台上',
#  '摇头',
#  '摇头晃脑',
#  '厉害',
#  '日常',
#  '日常生活',
#  '常生',
#  '生活',
#  '摇滚',
#  '人生',
#  '离经叛道',
#  '饭',
#  '吃',
#  '班',
#  '采访',
#  '大悲',
#  '乐队',
#  '主唱',
#  '华',
#  '罗丹',
#  '玩乐',
#  '乐队',
#  '所得',
#  '承担',
#  '生活',
#  '成本',
#  '乐队',
#  '成员',
#  '上班',
#  '上班族',
#  '工作',
#  '工作日',
#  '朝九晚五',
#  '周末',
#  '排练',
#  '实在',
#  '演出',
#  '工作',
#  '冲突',
#  '时',
#  '规规矩矩',
#  '规矩',
#  '矩',
#  '请假',
#  '问',
#  '一支',
#  '支乐队',
#  '乐队',
#  'Birdstriking',
#  '吉他',
#  '吉他手',
#  '说',
#  '感觉',
#  '太',
#  '摇滚',
#  '事',
#  '摇滚',
#  '精神',
#  '不意',
#  '意味',
#  '意味着',
#  '站',
#  '社会',
#  '规则',
#  '对立',
#  '对立面',
#  '立面',
#  '至少',
#  '巨星',
#  '饭',
#  '吃',
#  ...]
